# %% [markdown]
# # Fantasy Football Draft Simulator Capstone Project
# ### By: John Crawford, Christopher Hinshaw, Jack Horgan

# %% [markdown]
# Package and Data Import

# %%
from operator import itemgetter
import pandas as pd
import random
import numpy as np
import scipy.stats as stats

# %%
QBs = pd.read_csv('qb_stats_and_projections.csv')
RBs = pd.read_csv('rb_stats_and_projections.csv')
WRs = pd.read_csv('wr_stats_and_projections.csv')
TEs = pd.read_csv('te_stats_and_projections.csv')

# %% [markdown]
# Data Cleaning and Preparation

# %%
#Naming discrepancies across different positions, rename to make them all match
QBs = QBs.rename(columns = {'2020 RUSH YDS': '2020 RUSH YARDS'})
RBs = RBs.rename(columns = {'2020 REC YDS': '2020 REC YARDS'})
WRs = WRs.rename(columns = {'2020 REC TDS': '2020 REC TD', '2020 RUSH TDS':'2020 RUSH TD', 'POSITION':'PLAYER POSITION', '2020 RUSH CAR': '2020 CAR', 'TEAM': 'TEAM NAME'})
TEs = TEs.rename(columns = {'2020 RUSH CAR': '2020 CAR', '2020 REC YDS': '2020 REC YARDS', '2020 RUSH YDS': '2020 RUSH YARDS'})

# %%
ffprojections = pd.concat([QBs, RBs, WRs, TEs]) #concatenate into one major dataframe

# %%
#focus on columns that are important to fantasy points
ffprojections = ffprojections[['PLAYER NAME', 'TEAM NAME', 
                                     'PLAYER POSITION', '2020 CAR', '2020 RUSH YARDS',
                                     '2020 RUSH TD', '2020 REC', '2020 REC YARDS', '2020 REC TD', 
                                     '2020 PASSING YDS', '2020 PASSING TD', '2020 INT']]

# %%
ffprojections = ffprojections.rename(columns = {'PLAYER NAME': 'Player', 'TEAM NAME': 'Tm', 'PLAYER POSITION':'Pos',
                                  '2020 CAR':'Car', '2020 RUSH YARDS': 'RushYards', '2020 RUSH TD': 'RushTD',
                                  '2020 REC': 'Rec', '2020 REC YARDS': 'RecYards', '2020 REC TD': 'RecTD',
                                  '2020 PASSING YDS': 'PassYards', '2020 PASSING TD': 'PassTD', '2020 INT': 'Int'}).fillna(0)

# %% [markdown]
# __Fantasy Point Scoring System__ <br>
# __QB__<br>
#     Pass Yard | 0.04 <br>
#     Pass Touchdown | 4 <br>
#     Interception | -1 <br>
# __RB__ <br>
#     Rush Yard | 0.1 <br>
#     Rush Touchdown | 6 <br>
# __WR/TE__ <br>
#     Reception | 1 <br>
# Recieving Yard | 0.1 <br>
#     Receiving TD | 6 <br>

# %% [markdown]
# #### Generate Fantasy Point Datasets

# %%
#want as many random variables in our draft strategy analysis as possible
#randomize projections with multiplier to each stat from 0.925 to 1.075 
def rand_projections(ffprojections):

    rand_multiplier = 0.15 * np.random.random_sample((len(ffprojections), len(ffprojections.columns[3:]))) + 0.925
    
    #apply these scalar factors to numerical catefories
    ffprojections.iloc[:,3:] = ffprojections.iloc[:,3:] * rand_multiplier
    
    #compute projected fantasy points
    ffprojections['FPTS'] = ffprojections['RushYards'] * 0.1 + ffprojections['RushTD'] * 6 \
                        + ffprojections['Rec'] + ffprojections['RecYards'] * 0.1 + ffprojections['RecTD'] * 6 \
                        + ffprojections['PassYards'] * 0.04 + ffprojections['PassTD'] * 4 + ffprojections['Int'] * -1
    
    ffprojections = ffprojections[ffprojections['FPTS'] > 0] #clean players who aren't projected for any fantasy points
    ffprojections = ffprojections.sort_values('FPTS', ascending = False)
    
    #split back into positional dataframes to calculate positional z-scores
    RBs = ffprojections.loc[ffprojections['Pos'] == 'RB'].reset_index(drop = True)
    WRs = ffprojections.loc[ffprojections['Pos'] == 'WR'].reset_index(drop = True)
    TEs = ffprojections.loc[ffprojections['Pos'] == 'TE'].reset_index(drop = True)
    QBs = ffprojections.loc[ffprojections['Pos'] == 'QB'].reset_index(drop = True)
    
    #apply positional weights
    QBs['FPTS'] *= 0.8
    RBs['FPTS'] *= 1.02
    WRs['FPTS'] *= 0.98
    TEs['FPTS'] *= 1.1
    
    #calculate new column with z-scores for each position
    def z_score(df):
        df['Zscore'] = (df.loc[:, 'FPTS'] - df['FPTS'].mean()) / df['FPTS'].std()
        return df
    RBs = z_score(RBs)
    WRs = z_score(WRs)
    TEs = z_score(TEs)
    QBs = z_score(QBs)
    
    return QBs, RBs, WRs, TEs

# %%
QBs, RBs, WRs, TEs = rand_projections(ffprojections)

# %%
QBs.head(15) #check dataset
# Out:
#               Player          Tm Pos         Car   RushYards    RushTD  Rec  \
# 0      Lamar Jackson      Ravens  QB  147.434907  943.062397  6.423049  0.0
# 1    Patrick Mahomes      Chiefs  QB   63.334382  259.669245  2.811841  0.0
# 2     Deshaun Watson      Texans  QB   88.130508  549.763502  3.857264  0.0
# 3       Dak Prescott     Cowboys  QB   49.497906  232.393017  4.221296  0.0
# 4       Kyler Murray   Cardinals  QB   81.186015  467.689854  2.820539  0.0
# 5     Russell Wilson    Seahawks  QB   70.690090  373.232105  2.089691  0.0
# 6          Tom Brady  Buccaneers  QB   23.045516   28.551789  1.857863  0.0
# 7          Matt Ryan     Falcons  QB   31.296383  121.517235  1.054701  0.0
# 8       Carson Wentz      Eagles  QB   52.663621  202.373662  2.141215  0.0
# 9       Daniel Jones      Giants  QB   51.671173  271.201593  2.109694  0.0
# 10     Aaron Rodgers     Packers  QB   40.772186  208.436764  1.073939  0.0
# 11        Jared Goff        Rams  QB   30.847517   65.311260  2.045064  0.0
# 12   Jimmy Garoppolo       49ers  QB   42.666943   69.200555  2.066773  0.0
# 13  Matthew Stafford       Lions  QB   33.028255  128.093245  0.939412  0.0
# 14    Baker Mayfield      Browns  QB   33.430360  138.571937  2.145921  0.0
#
#     RecYards  RecTD    PassYards     PassTD        Int        FPTS    Zscore
# 0        0.0    0.0  3354.917831  24.519284  10.714126  283.523404  1.657563
# 1        0.0    0.0  4723.563022  30.256690  10.259886  274.037893  1.563996
# 2        0.0    0.0  4214.743698  26.356320  11.714967  272.335999  1.547208
# 3        0.0    0.0  4218.240130  27.624988  11.438471  253.086531  1.357328
# 4        0.0    0.0  3888.150812  27.325858  12.314963  252.965378  1.356132
# 5        0.0    0.0  3732.202865  30.084167   9.663933  247.857764  1.305750
# 6        0.0    0.0  4589.824585  28.855578   9.067982  243.159739  1.259408
# 7        0.0    0.0  4563.206481  28.600808  11.862800  242.838898  1.256243
# 8        0.0    0.0  3698.562476  28.714308   8.743511  229.712702  1.126763
# 9        0.0    0.0  3940.539978  24.336642  13.796474  224.760017  1.077909
# 10       0.0    0.0  3863.974312  25.278739   7.545086  220.332924  1.034239
# 11       0.0    0.0  4546.835559  20.861484  12.350485  217.416305  1.005469
# 12       0.0    0.0  3967.622384  26.539756  13.612835  216.457420  0.996011
# 13       0.0    0.0  3963.503806  25.385185  11.414517  213.689737  0.968710
# 14       0.0    0.0  3858.352664  24.232189  14.113144  211.105953  0.943223

# %% [markdown]
# ### The Draft

# %% [markdown]
# Our Draft Strategy: Take highest z-score difference between first and second players for a position <br>
# Autodraft Strategy: Take highest projected player across all positions

# %%
#This class stores the team information for all 12 teams in the fantasy draft
class Team:
    def __init__(self):
        #variable to store a list of the selected players for a team
        self.team = []

        #maximum amount of players that can be selected from one position
        self.player_types = {
            'QB': 2,
            'RB': 6,
            'WR': 8,
            'TE': 1
        }
        
    #function to draft players for our team
    def OurDraft(self):
        # Dictionary with possible choices; z-score difference as key and position as value
        choices = {QBs['Zscore'].iloc[0] - QBs['Zscore'].iloc[1]: [QBs, 'QB'],
                           RBs['Zscore'].iloc[0] - RBs['Zscore'].iloc[1]: [RBs, 'RB'],
                           WRs['Zscore'].iloc[0] - WRs['Zscore'].iloc[1]: [WRs, 'WR'],
                           TEs['Zscore'].iloc[0] - TEs['Zscore'].iloc[1]: [TEs, 'TE'] }
        
        #sort dictionary by greatest positional differential
        choices_sorted = dict(sorted(choices.items(), reverse = True))

        for x in choices_sorted.keys(): #cycle through values in dictionary in order of difference
            position_drafted = choices_sorted[x]
            if self.player_types[position_drafted[1]] > 0: #if we already have the max for this position, cycle to next highest difference
                self.team.append([position_drafted[0]['Player'].iloc[0], position_drafted[1]])  # 'draft' player
                position_drafted[0].drop(0, inplace=True) #drop from dataset because we 'drafted'
                position_drafted[0].reset_index(inplace=True, drop=True)
                self.player_types[position_drafted[1]] -= 1 #decrease max players for the position selected
                break #break out of loop once player has been drafted

    def AutoDraft(self):
        #QBs project for way more points than other positions, but since each team can only start one, they aren't as valuable
        #Apply positional weighting to projected fantasy points to get a more realistic and balanced draft

        
        #same code as OurDraft except they take top projected player overall
        choices =  {QBs['FPTS'].iloc[0] : [QBs, 'QB'],
                       RBs['FPTS'].iloc[0] : [RBs, 'RB'],
                       WRs['FPTS'].iloc[0] : [WRs, 'WR'],
                       TEs['FPTS'].iloc[0] : [TEs, 'TE'] }
        choices_sorted = dict(sorted(choices.items(), reverse = True))
        for x in choices_sorted.keys():
            position_drafted = choices_sorted[x]
            if self.player_types[position_drafted[1]] > 0: 
                self.team.append([position_drafted[0]['Player'].iloc[0], position_drafted[1]])
                position_drafted[0].drop(0, inplace=True)
                position_drafted[0].reset_index(inplace=True, drop=True)
                self.player_types[position_drafted[1]] -= 1 
                break 

    def get_team(self, sort = True):
        
        #sort by position
        if sort:
            return sorted(self.team, key=itemgetter(1))
        
        #sort by draft order
        else:
            return self.team

    def __str__(self):
        return str(self.team)

# %% [markdown]
# __Positions__: <br>
# QB <br>
# RB <br>
# RB <br>
# WR <br>
# WR <br>
# TE <br>
# FLEX (WR/RB/TE) <br>
# BENCH x10 <br>
# 17 total players

# %%
#function that automates a draft with inputted draft position for our team
def draft(draft_positon):
 #, QBs, RBs, WRs, TEs
    draft_board = [Team(), #initalize a draft board with 12 different teams
        Team(),
        Team(),
        Team(),
        Team(),
        Team(),
        Team(),
        Team(),
        Team(),
        Team(),
        Team(),
        Team()]

    num_rounds = 17 #number of rounds in the draft

    for i in range(0, num_rounds): #cycle through each round of a draft
        if not (i % 2): #if draft round is odd, normal order
            for j in range(0, 12):
                if j+1 == draft_positon:
                    draft_board[j].OurDraft()
                else:
                    draft_board[j].AutoDraft()
        else: #if draft round is even, reverse order (snake draft)
            for j in range(11, -1, -1):
                if j+1 == draft_positon:
                    draft_board[j].OurDraft()
                else:
                    draft_board[j].AutoDraft()
                    
    #Create dataframe to display draft board
    data = {}
    for x in range(0,12):
        if x+1 == draft_positon: 
            data['My Team'] = draft_board[x].get_team(sort = False)
        else: 
            data[f'Team {x + 1}'] = draft_board[x].get_team(sort = False)
    Draft = pd.DataFrame(data = data, index = range(1,num_rounds + 1))
    return Draft

# %%
draft_positon = random.randint(1, 12) #randomize spot to select
QBs, RBs, WRs, TEs = rand_projections(ffprojections)
Draft = draft(draft_positon)

# %%
Draft
# Out:
#                      My Team                    Team 2  \
# 1         [Travis Kelce, TE]         [Cooper Kupp, WR]
# 2         [Dak Prescott, QB]         [Tyreek Hill, WR]
# 3          [Josh Jacobs, RB]     [Jamison Crowder, WR]
# 4        [Aaron Rodgers, QB]          [Drew Brees, QB]
# 5        [Derrick Henry, RB]        [Chris Carson, RB]
# 6       [Saquon Barkley, RB]       [Jordan Howard, RB]
# 7       [Christian Kirk, WR]          [Tyler Boyd, WR]
# 8         [Chris Godwin, WR]     [Diontae Johnson, WR]
# 9     [James Washington, WR]  [Ben Roethlisberger, QB]
# 10       [Josh Reynolds, WR]        [Hunter Henry, TE]
# 11        [Nyheim Hines, RB]        [Jalen Reagor, WR]
# 12      [Mark Ingram II, RB]    [Mohamed Sanu Sr., WR]
# 13           [Cam Akers, RB]         [Corey Davis, WR]
# 14        [Keenan Allen, WR]  [Alexander Mattison, RB]
# 15        [Kenny Stills, WR]        [Tony Pollard, RB]
# 16  [Phillip Dorsett II, WR]       [Chase Edmonds, RB]
# 17        [Jake Kumerow, WR]       [Joshua Kelley, RB]
#
#                          Team 3                       Team 4  \
# 1              [Nick Chubb, RB]        [Patrick Mahomes, QB]
# 2          [Russell Wilson, QB]          [Lamar Jackson, QB]
# 3           [Davante Adams, WR]           [Le'Veon Bell, RB]
# 4               [Tom Brady, QB]            [T.Y. Hilton, WR]
# 5            [Kenyan Drake, RB]          [Melvin Gordon, RB]
# 6         [Kerryon Johnson, RB]            [Aaron Jones, RB]
# 7         [Phillip Lindsay, RB]         [Terry McLaurin, WR]
# 8          [Kenny Golladay, WR]              [Zach Ertz, TE]
# 9          [Raheem Mostert, RB]  [Clyde Edwards-Helaire, RB]
# 10           [Mark Andrews, TE]          [Jalen Richard, RB]
# 11       [Justin Jefferson, WR]        [Henry Ruggs III, WR]
# 12         [Alshon Jeffery, WR]           [J.K. Dobbins, RB]
# 13         [Devin Funchess, WR]        [Tyrell Williams, WR]
# 14  [Darrell Henderson Jr., RB]          [Tyler Johnson, WR]
# 15   [Laviska Shenault Jr., WR]         [Hunter Renfrow, WR]
# 16    [Michael Pittman Jr., WR]            [Allen Hurns, WR]
# 17        [Willie Snead IV, WR]            [Tee Higgins, WR]
#
#                       Team 5                       Team 6  \
# 1         [Alvin Kamara, RB]         [Michael Thomas, WR]
# 2        [David Johnson, RB]      [Leonard Fournette, RB]
# 3          [Dalvin Cook, RB]        [Ke'Shawn Vaughn, RB]
# 4           [Jared Goff, QB]        [Jimmy Garoppolo, QB]
# 5     [Devin Singletary, RB]              [Noah Fant, TE]
# 6    [Allen Robinson II, WR]          [Will Fuller V, WR]
# 7        [Austin Ekeler, RB]       [Courtland Sutton, WR]
# 8       [Dallas Goedert, TE]             [Joe Burrow, QB]
# 9          [Denzel Mims, WR]    [JuJu Smith-Schuster, WR]
# 10  [Gardner Minshew II, QB]           [Randall Cobb, WR]
# 11       [Sammy Watkins, WR]            [CeeDee Lamb, WR]
# 12      [Danny Amendola, WR]         [Adam Humphries, WR]
# 13      [DeSean Jackson, WR]          [Jarvis Landry, WR]
# 14        [N'Keal Harry, WR]              [Ito Smith, RB]
# 15       [Tevin Coleman, RB]            [Sony Michel, RB]
# 16    [Preston Williams, WR]  [Anthony McFarland Jr., RB]
# 17           [KJ Hamler, WR]            [Carlos Hyde, RB]
#
#                        Team 7                    Team 8  \
# 1          [Kyler Murray, QB]        [Daniel Jones, QB]
# 2   [Christian McCaffrey, RB]     [DeAndre Hopkins, WR]
# 3            [Mike Evans, WR]  [Dwayne Haskins Jr., QB]
# 4        [Ryan Tannehill, QB]          [DK Metcalf, WR]
# 5          [DJ Chark Jr., WR]       [Curtis Samuel, WR]
# 6        [Todd Gurley II, RB]         [Evan Engram, TE]
# 7         [Darren Waller, TE]       [Derrius Guice, RB]
# 8          [Deebo Samuel, WR]        [Stefon Diggs, WR]
# 9        [Michael Gallup, WR]         [Tarik Cohen, RB]
# 10         [Duke Johnson, RB]      [DeVante Parker, WR]
# 11      [Jamaal Williams, RB]     [Ronald Jones II, RB]
# 12          [Matt Breida, RB]        [Chris Conley, WR]
# 13     [Emmanuel Sanders, WR]        [Cole Beasley, WR]
# 14         [Miles Boykin, WR]       [Mike Williams, WR]
# 15         [Ted Ginn Jr., WR]      [Antonio Gibson, RB]
# 16         [Allen Lazard, WR]          [Dion Lewis, RB]
# 17        [Rashaad Penny, RB]         [Gus Edwards, RB]
#
#                     Team 9                 Team 10  \
# 1         [A.J. Brown, WR]  [Marvin Jones Jr., WR]
# 2        [Sam Darnold, QB]   [Ezekiel Elliott, RB]
# 3         [Derek Carr, QB]      [James Conner, RB]
# 4      [Calvin Ridley, WR]      [Kirk Cousins, QB]
# 5      [Austin Hooper, TE]         [Matt Ryan, QB]
# 6       [Adam Thielen, WR]      [Tyler Higbee, TE]
# 7           [DJ Moore, WR]    [Robby Anderson, WR]
# 8     [Darius Slayton, WR]        [John Brown, WR]
# 9      [Tyler Lockett, WR]  [Sterling Shepard, WR]
# 10   [Damien Williams, RB]    [Anthony Miller, WR]
# 11   [Jonathan Taylor, RB]       [James White, RB]
# 12  [David Montgomery, RB]    [Julian Edelman, WR]
# 13   [Parris Campbell, WR]       [Golden Tate, WR]
# 14       [Marlon Mack, RB]     [Brandon Aiyuk, WR]
# 15      [Boston Scott, RB]   [Latavius Murray, RB]
# 16    [Dede Westbrook, WR]   [Darrynton Evans, RB]
# 17        [Frank Gore, RB]     [Patrick Laird, RB]
#
#                        Team 11                 Team 12
# 1             [Josh Allen, QB]     [George Kittle, TE]
# 2      [Odell Beckham Jr., WR]      [Amari Cooper, WR]
# 3          [D'Andre Swift, RB]        [A.J. Green, WR]
# 4         [Rob Gronkowski, TE]         [Joe Mixon, RB]
# 5         [Marquise Brown, WR]     [Brandin Cooks, WR]
# 6          [Miles Sanders, RB]    [Mecole Hardman, WR]
# 7      [Teddy Bridgewater, QB]    [Deshaun Watson, QB]
# 8       [Breshad Perriman, WR]       [Kareem Hunt, RB]
# 9            [Julio Jones, WR]    [Tua Tagovailoa, QB]
# 10         [Albert Wilson, WR]      [Robert Woods, WR]
# 11             [Zack Moss, RB]   [Steven Sims Jr., WR]
# 12  [Antonio Gandy-Golden, WR]   [Giovani Bernard, RB]
# 13           [Jerry Jeudy, WR]    [Justin Jackson, RB]
# 14       [Jerick McKinnon, RB]  [Larry Fitzgerald, WR]
# 15          [Russell Gage, WR]    [Chris Thompson, RB]
# 16        [Jaylen Samuels, RB]    [Chase Claypool, WR]
# 17       [Lynn Bowden Jr., RB]   [Adrian Peterson, RB]

# %% [markdown]
# ### Creating Head-to-Head Weekly Matchups and Calculating Record

# %%
#Adds up the points from the players for each week for each team
class lineUp:
    def __init__(self, team, week, team_name):
        self.team = team #same team list from Team() class
        self.week = week #week number (1-17)
        self.team_name = team_name
        self.line_up = pd.DataFrame(columns = [ 'Player', 'Pos', 'FPTS']) #fill out empty dataframe with starting players for each week

    def getPoints(self):
        
        #Intialize dataframe with team list
        points = pd.DataFrame(self.team)
        
        #Split lists into player and position columns
        points[['Player','Pos']] = pd.DataFrame(points[self.team_name].tolist(), index= points.index)
        points = points.drop(self.team_name, axis = 1)
        
        #match up our team with weekly scoring dataframe through merge (way faster than iteration)
        points = points.merge(weekly_data[week], on = ['Player', 'Pos'], how = 'left')
        points['FPTS'] = points['PPRFantasyPoints'].fillna(0)
        points = points.drop('PPRFantasyPoints', axis = 1)
        return points
    
    #Now that we have all our players with their point values, need to set starting lineup
    #Starting lineup automatically optimized after weekly scoring -- best ball format, no setting lineups
    def getLineUp(self, points):
        
        #sort each position by fantasy points scored
        QBs = points[points['Pos'] == 'QB'].sort_values('FPTS', ascending = False)
        RBs = points[points['Pos'] == 'RB'].sort_values('FPTS', ascending = False)
        WRs = points[points['Pos'] == 'WR'].sort_values('FPTS', ascending = False)
        TEs = points[points['Pos'] == 'TE'].sort_values('FPTS', ascending = False)
        
        self.line_up.loc[len(self.line_up.index)] = QBs.iloc[0] #start top scoring QB
        
        self.line_up.loc[len(self.line_up.index)] = RBs.iloc[0] #start top scoring RB
        
        self.line_up.loc[len(self.line_up.index)] = RBs.iloc[1] #start second highest scoring RB

        self.line_up.loc[len(self.line_up.index)] = WRs.iloc[0] #start top scoring WR
        
        self.line_up.loc[len(self.line_up.index)] = WRs.iloc[1] #start second highest scoring WR
        
        self.line_up.loc[len(self.line_up.index)] = TEs.iloc[0] #start top scoring TE
        
        #still need to fill out flex position (any player except a QB)
        #combine remaining players into dataset
        Flex = pd.concat([RBs.iloc[2: , :], WRs.iloc[2: , :], TEs.iloc[1: , :]]).sort_values('FPTS', ascending = False)
        
        self.line_up.loc[len(self.line_up.index)] = Flex.iloc[0] #start highest scoring remaining non-QB
        
        #display positions - no column name for aesthetic purposes when printing dataframe
        self.line_up[' '] = ['QB', 'RB1', 'RB2', 'WR1', 'WR2', 'TE', 'Flex']
        self.line_up.set_index(' ', inplace = True)

    def printLineUp(self):
        #print the team name, the starting lineup, and the total fantasy points scored
        print(f'\n \033[1m {self.team_name}: \033[0m \n {self.line_up} \n \n Total Points: {self.getTotal()} \n')

    def getTotal(self):
        return round(sum(self.line_up.FPTS), 2)

# %%
#randomize schedule of opponents
#play every team once, then play remaining weeks with random teams
def random_opponents(draft_position, num_weeks):
    if num_weeks < 12:
        raise Exception('Season is too short! Need at least 12 weeks')
    opponent_list = []
    for x in range(1, 13):
        if x != draft_position:
            opponent_list.append(x)
    n = num_weeks - 11
    while n > 0:
        rand_team = random.randint(1,12)
        while rand_team == draft_position: #if random team is our team, keep randomizing until it isn't
            rand_team = random.randint(1,12)
        opponent_list.append(rand_team)
        n -= 1
        
    #randomize entire schedule
    random.shuffle(opponent_list)

    return opponent_list

# %%
random_opponents(4, 13) #first parameter our team's draft position, second paramter # of weeks to make a schedule for
# Out:
# [3, 5, 6, 8, 12, 1, 2, 7, 10, 9, 8, 11, 8]

# %% [markdown]
# Note: If the code below is taking a long time to run, it is most likely an issue with the github datasource not loading - usually works after a bit

# %%
#load in weekly scoring dataframe in a dictionary: week # as key and data for that week as values
weekly_data = {}
for x in range(1, 17):
    temp = pd.read_csv(f'https://raw.githubusercontent.com/fantasydatapros/data/master/weekly/2020/week{x}.csv') #scrape data
    temp = temp.loc[temp['Pos'].isin(['QB', 'RB', 'WR', 'TE'])]
    weekly_data[x] = temp[['Player', 'Pos','PPRFantasyPoints']]

# %%
#17 weeks in football season, most fantasy leagues only play through first 16 because many players rest during week 17
num_weeks = 16


opponents_list = random_opponents(draft_positon, num_weeks) #draft_position variable from earlier
opponents = {}
for x, i in enumerate(opponents_list):
    opponents[x] = Draft[f'Team {i}']

my_team_totals = []
opponent_totals = []

for week in range(1, num_weeks + 1): #cycle through each week
    my_team_lineup = lineUp(Draft['My Team'], week, 'My Team') #initialize class
    my_team_lineup.getLineUp(my_team_lineup.getPoints())
    print(f'-----\tWeek {week}\t-----') #print week number
    my_team_lineup.printLineUp() #print our team and score
    my_team_totals.append(my_team_lineup.getTotal()) #append to list to calculate record
    
    opponent_lineup = lineUp(opponents[week - 1], week, f'Team {opponents_list[week - 1]}') #initalize class for opponent team
    opponent_lineup.getLineUp(opponent_lineup.getPoints())
    opponent_lineup.printLineUp()
    opponent_totals.append(opponent_lineup.getTotal())

wins = 0
losses = 0

#calculate record
for week in range(num_weeks):
    if my_team_totals[week] > opponent_totals[week]:
        wins += 1
    else:
        losses += 1

print('---------------------')
print(f'Record: {wins} - {losses}')
print(f'Average Points: {sum(my_team_totals) / num_weeks}')
# Out:
# -----	Week 1	-----
#
#   My Team:
#                    Player Pos   FPTS
#
# QB    Gardner Minshew II  QB  20.82
# RB1        David Johnson  RB   19.9
# RB2        Melvin Gordon  RB   15.6
# WR1        Sammy Watkins  WR   21.5
# WR2        Mike Williams  WR   10.9
# TE             Zach Ertz  TE   10.8
# Flex     Jonathan Taylor  RB   14.9
#
#  Total Points: 114.42
#
#
#   Team 7:
#                 Player Pos   FPTS
#
# QB     Deshaun Watson  QB  20.82
# RB1     Chase Edmonds  RB   13.5
# RB2        Nick Chubb  RB    5.6
# WR1    Marquise Brown  WR   15.1
# WR2   Diontae Johnson  WR    9.7
# TE      Darren Waller  TE   10.5
# Flex      Jerry Jeudy  WR    9.6
#
#  Total Points: 84.82
#
# -----	Week 2	-----
#
#   My Team:
#                    Player Pos   FPTS
#
# QB    Gardner Minshew II  QB  23.46
# RB1      Jonathan Taylor  RB   19.0
# RB2        Austin Ekeler  RB   18.8
# WR1         Keenan Allen  WR   16.6
# WR2       Adam Humphries  WR   15.8
# TE             Zach Ertz  TE    9.2
# Flex       Melvin Gordon  RB   16.4
#
#  Total Points: 119.26
#
#
#   Team 2:
#                   Player Pos   FPTS
#
# QB            Matt Ryan  QB  28.52
# RB1     Ezekiel Elliott  RB   22.2
# RB2     Jerick McKinnon  RB   13.7
# WR1   Odell Beckham Jr.  WR   17.4
# WR2        Adam Thielen  WR    6.1
# TE          Evan Engram  TE   12.5
# Flex     Mecole Hardman  WR    5.3
#
#  Total Points: 105.72
#
# -----	Week 3	-----
#
#   My Team:
#                    Player Pos  FPTS
#
# QB    Gardner Minshew II  QB   9.2
# RB1        Austin Ekeler  RB  31.3
# RB2      Jonathan Taylor  RB  13.2
# WR1         Keenan Allen  WR  30.2
# WR2        Sammy Watkins  WR  13.2
# TE             Zach Ertz  TE  14.0
# Flex       David Johnson  RB  12.6
#
#  Total Points: 123.7
#
#
#   Team 4:
#                  Player Pos   FPTS
#
# QB        Kirk Cousins  QB  19.44
# RB1          Joe Mixon  RB    8.5
# RB2      D'Andre Swift  RB    2.9
# WR1   Justin Jefferson  WR   30.5
# WR2       Randall Cobb  WR   19.5
# TE           Noah Fant  TE    9.6
# Flex     Calvin Ridley  WR   16.7
#
#  Total Points: 107.14
#
# -----	Week 4	-----
#
#   My Team:
#                    Player Pos   FPTS
#
# QB    Gardner Minshew II  QB  20.94
# RB1        Melvin Gordon  RB   25.8
# RB2        David Johnson  RB   11.2
# WR1         Keenan Allen  WR   14.2
# WR2        Sammy Watkins  WR    6.3
# TE             Zach Ertz  TE    4.9
# Flex     Jonathan Taylor  RB    8.9
#
#  Total Points: 92.24
#
#
#   Team 10:
#                 Player Pos   FPTS
#
# QB      Aaron Rodgers  QB  29.58
# RB1       Dalvin Cook  RB   28.6
# RB2   Ronald Jones II  RB   18.8
# WR1     Brandon Aiyuk  WR   13.6
# WR2       Tee Higgins  WR   13.0
# TE       Hunter Henry  TE    5.9
# Flex      T.Y. Hilton  WR    5.9
#
#  Total Points: 115.38
#
# -----	Week 5	-----
#
#   My Team:
#                    Player Pos   FPTS
#
# QB    Gardner Minshew II  QB  19.84
# RB1      Jonathan Taylor  RB   15.4
# RB2        David Johnson  RB   12.3
# WR1        Mike Williams  WR   27.9
# WR2         Keenan Allen  WR   10.9
# TE             Zach Ertz  TE    1.6
# Flex       Sammy Watkins  WR   10.4
#
#  Total Points: 98.34
#
#
#   Team 9:
#                       Player Pos   FPTS
#
# QB           Baker Mayfield  QB  15.58
# RB1             Josh Jacobs  RB   22.5
# RB2   Clyde Edwards-Helaire  RB   11.0
# WR1         DeAndre Hopkins  WR   25.1
# WR2          Michael Gallup  WR   11.3
# TE           T.J. Hockenson  TE    0.0
# Flex           Le'Veon Bell  RB    7.7
#
#  Total Points: 93.18
#
# -----	Week 6	-----
#
#   My Team:
#                    Player Pos   FPTS
#
# QB    Gardner Minshew II  QB  18.12
# RB1      Jonathan Taylor  RB   15.5
# RB2        David Johnson  RB   13.9
# WR1       Adam Humphries  WR   18.4
# WR2        Josh Reynolds  WR   12.5
# TE             Zach Ertz  TE    7.3
# Flex       Tyler Johnson  WR    7.7
#
#  Total Points: 93.42
#
#
#   Team 2:
#                 Player Pos   FPTS
#
# QB          Matt Ryan  QB  31.64
# RB1   Adrian Peterson  RB   12.8
# RB2   Ezekiel Elliott  RB   12.0
# WR1      Deebo Samuel  WR   18.0
# WR2      Adam Thielen  WR   14.1
# TE        Evan Engram  TE    5.0
# Flex  Phillip Lindsay  RB   10.1
#
#  Total Points: 103.64
#
# -----	Week 7	-----
#
#   My Team:
#                    Player Pos   FPTS
#
# QB    Gardner Minshew II  QB  17.02
# RB1         Boston Scott  RB   18.2
# RB2        David Johnson  RB   16.4
# WR1         Keenan Allen  WR   22.5
# WR2        Josh Reynolds  WR   15.2
# TE             Zach Ertz  TE    0.0
# Flex       Melvin Gordon  RB   12.0
#
#  Total Points: 101.32
#
#
#   Team 8:
#                     Player Pos  FPTS
#
# QB       Matthew Stafford  QB  18.4
# RB1         Derrick Henry  RB  15.2
# RB2      David Montgomery  RB  11.9
# WR1   JuJu Smith-Schuster  WR  17.5
# WR2           Corey Davis  WR  15.5
# TE             Jared Cook  TE  12.2
# Flex         Stefon Diggs  WR  10.8
#
#  Total Points: 101.5
#
# -----	Week 8	-----
#
#   My Team:
#               Player Pos   FPTS
#
# QB        Drew Lock  QB  19.82
# RB1   Melvin Gordon  RB   10.7
# RB2    Boston Scott  RB    9.9
# WR1    Keenan Allen  WR   21.7
# WR2   Mike Williams  WR   21.0
# TE        Zach Ertz  TE    0.0
# Flex  Josh Reynolds  WR    8.4
#
#  Total Points: 91.52
#
#
#   Team 6:
#                Player Pos  FPTS
#
# QB        Drew Brees  QB  19.6
# RB1     Tony Pollard  RB   8.4
# RB2    Joshua Kelley  RB   3.5
# WR1   Hunter Renfrow  WR  12.6
# WR2     Jalen Reagor  WR  11.2
# TE      Travis Kelce  TE  24.9
# Flex  DeVante Parker  WR   7.3
#
#  Total Points: 87.5
#
# -----	Week 9	-----
#
#   My Team:
#                 Player Pos   FPTS
#
# QB          Drew Lock  QB  29.22
# RB1   Jonathan Taylor  RB    9.4
# RB2     Melvin Gordon  RB    3.7
# WR1      Keenan Allen  WR   25.3
# WR2     Mike Williams  WR   13.1
# TE          Zach Ertz  TE    0.0
# Flex   Michael Thomas  WR   10.1
#
#  Total Points: 90.82
#
#
#   Team 12:
#                Player Pos   FPTS
#
# QB      Daniel Jones  QB  12.88
# RB1      Aaron Jones  RB   12.9
# RB2    Jordan Howard  RB    7.9
# WR1   Christian Kirk  WR   23.3
# WR2      Julio Jones  WR   16.4
# TE      Mark Andrews  TE    5.2
# Flex  Chase Claypool  WR   15.3
#
#  Total Points: 93.88
#
# -----	Week 10	-----
#
#   My Team:
#                 Player Pos  FPTS
#
# QB          Drew Lock  QB  6.98
# RB1      Boston Scott  RB  14.4
# RB2   Jonathan Taylor  RB   5.7
# WR1     Josh Reynolds  WR  17.4
# WR2      Keenan Allen  WR  12.9
# TE          Zach Ertz  TE   0.0
# Flex    Mike Williams  WR   5.8
#
#  Total Points: 63.18
#
#
#   Team 7:
#                 Player Pos   FPTS
#
# QB     Deshaun Watson  QB  14.12
# RB1        Nick Chubb  RB   18.6
# RB2     Chase Edmonds  RB   10.7
# WR1   Diontae Johnson  WR   23.6
# WR2       Jerry Jeudy  WR   10.8
# TE      Darren Waller  TE    6.7
# Flex       Tyler Boyd  WR   10.1
#
#  Total Points: 94.62
#
# -----	Week 11	-----
#
#   My Team:
#                 Player Pos  FPTS
#
# QB          Drew Lock  QB  11.1
# RB1     Melvin Gordon  RB  18.4
# RB2   Jonathan Taylor  RB  15.4
# WR1      Keenan Allen  WR  34.5
# WR2    Michael Thomas  WR  19.4
# TE          Zach Ertz  TE   0.0
# Flex    Mike Williams  WR  17.2
#
#  Total Points: 116.0
#
#
#   Team 4:
#                  Player Pos   FPTS
#
# QB        Kirk Cousins  QB  22.96
# RB1       Duke Johnson  RB    6.5
# RB2     Saquon Barkley  RB    0.0
# WR1      Davante Adams  WR   23.6
# WR2   Justin Jefferson  WR   17.6
# TE           Noah Fant  TE    9.5
# Flex        Mike Evans  WR   15.9
#
#  Total Points: 96.06
#
# -----	Week 12	-----
#
#   My Team:
#                Player Pos  FPTS
#
# QB         Drew Lock  QB   0.0
# RB1    Austin Ekeler  RB  23.9
# RB2     Boston Scott  RB   9.7
# WR1     Keenan Allen  WR  14.0
# WR2   Michael Thomas  WR   9.1
# TE         Zach Ertz  TE   0.0
# Flex   Josh Reynolds  WR   9.0
#
#  Total Points: 65.7
#
#
#   Team 4:
#                  Player Pos   FPTS
#
# QB        Kirk Cousins  QB  24.18
# RB1       Duke Johnson  RB   17.0
# RB2         Dion Lewis  RB    2.7
# WR1   Justin Jefferson  WR   26.0
# WR2         Mike Evans  WR   20.0
# TE           Noah Fant  TE    2.3
# Flex     Davante Adams  WR   18.1
#
#  Total Points: 110.28
#
# -----	Week 13	-----
#
#   My Team:
#                 Player Pos   FPTS
#
# QB          Drew Lock  QB  10.94
# RB1   Jonathan Taylor  RB   22.5
# RB2     Melvin Gordon  RB   15.2
# WR1    Michael Thomas  WR   19.5
# WR2      Keenan Allen  WR    9.8
# TE          Zach Ertz  TE    5.1
# Flex    Austin Ekeler  RB   10.8
#
#  Total Points: 93.84
#
#
#   Team 1:
#                     Player Pos  FPTS
#
# QB             Josh Allen  QB  30.1
# RB1           James White  RB   3.1
# RB2   Christian McCaffrey  RB   0.0
# WR1          Cole Beasley  WR  28.0
# WR2           Tyreek Hill  WR  14.8
# TE           Tyler Higbee  TE  12.4
# Flex        Tyler Lockett  WR  12.3
#
#  Total Points: 100.7
#
# -----	Week 14	-----
#
#   My Team:
#                 Player Pos  FPTS
#
# QB          Drew Lock  QB  25.6
# RB1   Jonathan Taylor  RB  30.5
# RB2     Austin Ekeler  RB  23.6
# WR1      Keenan Allen  WR  20.2
# WR2    Michael Thomas  WR  16.4
# TE          Zach Ertz  TE   2.8
# Flex    Melvin Gordon  RB  12.1
#
#  Total Points: 131.2
#
#
#   Team 9:
#                       Player Pos   FPTS
#
# QB            Lamar Jackson  QB  34.92
# RB1   Clyde Edwards-Helaire  RB   14.1
# RB2            Nyheim Hines  RB   11.5
# WR1         DeAndre Hopkins  WR   22.6
# WR2        Breshad Perriman  WR    5.6
# TE           T.J. Hockenson  TE   16.3
# Flex            Josh Jacobs  RB   10.4
#
#  Total Points: 115.42
#
# -----	Week 15	-----
#
#   My Team:
#                    Player Pos   FPTS
#
# QB    Gardner Minshew II  QB  15.94
# RB1        David Johnson  RB   24.3
# RB2        Melvin Gordon  RB   24.1
# WR1        Sammy Watkins  WR   10.0
# WR2        Mike Williams  WR    4.2
# TE             Zach Ertz  TE    8.9
# Flex     Jonathan Taylor  RB   19.5
#
#  Total Points: 106.94
#
#
#   Team 5:
#                  Player Pos   FPTS
#
# QB       Philip Rivers  QB  17.02
# RB1       Alvin Kamara  RB   18.4
# RB2       J.K. Dobbins  RB   15.1
# WR1       Chris Godwin  WR   13.6
# WR2   Emmanuel Sanders  WR   11.6
# TE      Rob Gronkowski  TE    5.9
# Flex       Sony Michel  RB    9.2
#
#  Total Points: 90.82
#
# -----	Week 16	-----
#
#   My Team:
#                 Player Pos   FPTS
#
# QB          Drew Lock  QB  14.06
# RB1     David Johnson  RB   28.9
# RB2   Jonathan Taylor  RB   19.4
# WR1     Josh Reynolds  WR   13.0
# WR2     Mike Williams  WR    9.4
# TE          Zach Ertz  TE    6.3
# Flex    Austin Ekeler  RB   15.8
#
#  Total Points: 106.86
#
#
#   Team 11:
#                 Player Pos   FPTS
#
# QB    Patrick Mahomes  QB  19.22
# RB1         AJ Dillon  RB   25.9
# RB2       Kareem Hunt  RB   14.2
# WR1       CeeDee Lamb  WR   23.4
# WR2     Curtis Samuel  WR   20.8
# TE      George Kittle  TE   13.2
# Flex        Zack Moss  RB   12.7
#
#  Total Points: 129.42
#
# ---------------------
# Record: 8 - 8
# Average Points: 100.54749999999999

# %% [markdown]
# ## Simulating Results

# %% [markdown]
# Can't just use one season as indication of how good our strategy is, need to evaluate win percentage over 'n' simulations <br>
# __Change n value on first line below to a lower number if you want this to run quickly__

# %%
n= 100 # number of simulations 

num_weeks = 16 # number of weeks per simulation
win_list = np.array([]) #record wins for each season
loss_list = np.array([]) #record losses for each season

while n > 0:    
    QBs, RBs, WRs, TEs = rand_projections(ffprojections)


    draft_positon = random.randint(1, 12) #randomize spot to select

    Draft = draft(draft_positon)


    opponents_list = random_opponents(draft_positon, num_weeks)
    opponents = {}
    for x, i in enumerate(opponents_list):
        opponents[x] = Draft[f'Team {i}']

    my_team_totals = []
    opponent_totals = []

    for week in range(1, num_weeks + 1):
        my_team_lineup = lineUp(Draft['My Team'], week, 'My Team')
        my_team_lineup.getLineUp(my_team_lineup.getPoints())
        my_team_totals.append(my_team_lineup.getTotal())
        opponent_lineup = lineUp(opponents[week - 1], week, f'Team {opponents_list[week - 1]}')
        opponent_lineup.getLineUp(opponent_lineup.getPoints())
        opponent_totals.append(opponent_lineup.getTotal())

    wins = 0
    losses = 0
    for week in range(num_weeks):
        if my_team_totals[week] > opponent_totals[week]:
            wins += 1
        else:
            losses += 1
    win_list = np.append(win_list, [wins])
    loss_list = np.append(loss_list, [losses])
    if n % 5 == 0:
        print(f'Simulations Left: {n}')
    n -= 1
print('Simulations Complete! win_list and loss_list can now be used')
# Out:
# Simulations Left: 100
# Simulations Left: 95
# Simulations Left: 90
# Simulations Left: 85
# Simulations Left: 80
# Simulations Left: 75
# Simulations Left: 70
# Simulations Left: 65
# Simulations Left: 60
# Simulations Left: 55
# Simulations Left: 50
# Simulations Left: 45
# Simulations Left: 40
# Simulations Left: 35
# Simulations Left: 30
# Simulations Left: 25
# Simulations Left: 20
# Simulations Left: 15
# Simulations Left: 10
# Simulations Left: 5
# Simulations Complete! win_list and loss_list can now be used

# %%
win_percentage = win_list.mean() / (win_list.mean() + loss_list.mean()) 
win_percentage
# Out:
# 0.49875

# %% [markdown]
# Compare Our Simulated Average Wins with expected wins, num_weeks / 2 (50% win rate) <br>
# Use one-sample T-test and derive p-value <br>
# If p-value is greater than our selected alpha value of 0.05, then it is significant

# %%
p_value = stats.ttest_1samp(win_list, popmean= (num_weeks / 2)).pvalue
print(f'p_value: {p_value} \n')
if win_percentage < 0.5 and p_value > 0.05:
    print('Our Draft Strategy is not significantly better than AutoDraft!')
else:
    print('Our Draft Strategy is better than AutoDraft!')
# Out:
# p_value: 0.9468311560277882
#
# Our Draft Strategy is not significantly better than AutoDraft!
